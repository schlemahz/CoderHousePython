# %% [markdown]
# # Matplotlib

# %% [markdown]
# Pyplot

# %%
#importações padrões

import pandas as pd
import numpy as np

# %%
pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    -------------------- ------------------- 3.9/7.8 MB 20.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 24.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 32.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 38.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#importação pyplot
import matplotlib.pyplot as plt

# %%
#y=2x
a=list(range(11))
b=list(pd.Series(a)*2)
plt.plot(a,b)

# %%
#y=-x²+2x-10
x=list(range(-10,13))
y=list(pd.Series(x)**2*(-1)+2*pd.Series(x)-10)
plt.plot(x,y)

# %%
#orientada ao estado
plt.plot([1,2],[3,4])

# %%
#orientada ao objeto
fig,ax = plt.subplots()
ax.plot([1,2],[3,4])

# %%
##Tipos de gráficos
x=list(range(5)) 
y=list(pd.Series(x)**2+2)
z=['Alfa', 'Beta', 'Gamma', 'Epsilon','Lambda']
print('x: ',x,"\n",'y: ',y,"\n",'z: ',z)
# Out:
# x:  [0, 1, 2, 3, 4]
#  y:  [2, 3, 6, 11, 18]
#  z:  ['Alfa', 'Beta', 'Gamma', 'Epsilon', 'Lambda']

# %%
#linha
fig,ax = plt.subplots()
ax.plot(x,y)

# %%
#barras
fig,ax = plt.subplots()
ax.bar(y,z)
# Out:
# <BarContainer object of 5 artists>

# %%
#colunas
fig,ax = plt.subplots()
ax.barh(z,y)
# Out:
# <BarContainer object of 5 artists>

# %%
#pizza ou setores
fig,ax = plt.subplots()
ax.pie(y, labels=z)
# Out:
# ([<matplotlib.patches.Wedge at 0x19b721a5550>,
# ...
#  [Text(1.086457173902475, 0.1720779162933093, 'Alfa'),
#   Text(0.9379041891252708, 0.5747484075848044, 'Beta'),
#   Text(0.33991865722907993, 1.0461621798113232, 'Gamma'),
#   Text(-0.9379043764020233, 0.5747481019767982, 'Epsilon'),
#   Text(0.1720779940070747, -1.0864571615938208, 'Lambda')])

# %%
#dispersão
fig,ax = plt.subplots()
ax.scatter(x,y)

# %%
#histograma
np.random.seed(18)
k=np.random.randint(0,100,1000)
fig,ax = plt.subplots()
ax.hist(k)
# Out:
# (array([ 83.,  98.,  97.,  95.,  93., 104., 102., 117., 105., 106.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
fig,ax = plt.subplots()
ax.hist(k, bins=20)
# Out:
# (array([40., 43., 51., 47., 54., 43., 55., 40., 42., 51., 46., 58., 50.,
#         52., 52., 65., 45., 60., 58., 48.]),
#  array([ 0.  ,  4.95,  9.9 , 14.85, 19.8 , 24.75, 29.7 , 34.65, 39.6 ,
#         44.55, 49.5 , 54.45, 59.4 , 64.35, 69.3 , 74.25, 79.2 , 84.15,
#         89.1 , 94.05, 99.  ]),
#  <BarContainer object of 20 artists>)

# %%
#área
fig,ax = plt.subplots()
ax.fill_between(x,y)

# %%
#Configurações

# %%
fig,ax = plt.subplots()
#cor 
ax.plot(x,y, color='lightgreen')
#titulo
ax.set_title("Gráfico de linha X e Y")
#etiqueta dos eixos
ax.set_xlabel('Eixo x')
ax.set_ylabel('Eixo y')
#limites dos eixos
ax.set_ylim(0,30)
# ax.set_xlim(-1,5)
# #cor
ax.set_xscale('log')

# %%
fig,ax = plt.subplots()
#cor 
ax.plot(x,y, color='lightgreen')
#tipo de linha e marcadores
ax.plot(x,pd.Series(y)-5, color='magenta', ls='--', lw=0.5, marker='.', markersize=20)
#transparencia
ax.plot(x,[1]*len(x), alpha=0.3, color='orange')
# #titulo
ax.set_title("Gráfico de linha X e Y")
# #etiqueta dos eixos
ax.set_xlabel('Eixo x')
ax.set_ylabel('Eixo y')
# #limites dos eixos
ax.set_xlim(-1)
ax.set_ylim(-5)
ax.grid(True)

# %%
#subplot
fig,axs = plt.subplots(2,2, figsize=(10,8))
axs[0,0].plot(x,y)
axs[0,0].set_title('Grafico linha X²+2')
axs[1,0].bar(z,y)
axs[1,0].set_title('Grafico de barras')
axs[0,1].hist(k, bins=4)
axs[0,1].set_title('Histrograma')
axs[1,1].pie(y, labels=z)
axs[1,1].set_title('Grafico de Pizza')
# Out:
# Text(0.5, 1.0, 'Grafico de Pizza')

# %%
fig,axs = plt.subplots(4,1, figsize=(10,15))
axs[0].plot(x,y)
axs[0].set_title('Grafico linha X²+2')
axs[1].bar(z,y)
axs[1].set_title('Grafico de barras')
axs[2].hist(k, bins=4)
axs[2].set_title('Histrograma')
axs[3].pie(y, labels=z)
axs[3].set_title('Grafico de Pizza')
# Out:
# Text(0.5, 1.0, 'Grafico de Pizza')

# %% [markdown]
# # Seaborn

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#importação seaborn

import seaborn as sns

# %%
#atribuindo temas
sns.lineplot(x=x,y=y)
# Out:
# <Axes: >

# %%
sns.lineplot(x=x,y=y)
sns.set_theme(style='ticks')

# %%
#distribuição de dados
np.random.seed(16)
k=np.random.normal(size=10)
sns.displot(k, kde=True)

# %%
np.random.seed(16)
k=np.random.normal(size=100)
sns.displot(k, kde=True)

# %%
np.random.seed(16)
k=np.random.normal(size=1000)
sns.displot(k, kde=True)

# %%
#leitura de base
carros=pd.read_csv('Dataset - Venda de Carros .csv', sep=';', encoding='latin1', decimal=',')
carros.head()
# Out:
#   Nome_Carro  Ano_Fabricação  Preço_Venda  Preço_Atual  Km_Rodados Tipo_Motor  \
# 0       ritz            2014         3.35         5.59     27000.0   Gasolina
# 1        sx4            2013         4.75         9.54     43000.0     Diesel
# 2       ciaz            2017         7.25         9.85      6900.0   Gasolina
# 3    wagon r            2011         2.85         4.15      5200.0   Gasolina
# 4      swift            2014         4.60         6.87     42450.0     Diesel
#
#    Tipo_Vendedor Transmissão  Donos
# 0  Intermediária      Manual      0
# 1  Intermediária      Manual      0
# 2  Intermediária      Manual      0
# 3  Intermediária      Manual      0
# 4  Intermediária      Manual      0

# %%
carros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nome_Carro      301 non-null    object
#  1   Ano_Fabricação  301 non-null    int64
#  2   Preço_Venda     299 non-null    float64
#  3   Preço_Atual     297 non-null    float64
#  4   Km_Rodados      297 non-null    float64
#  5   Tipo_Motor      300 non-null    object
#  6   Tipo_Vendedor   301 non-null    object
#  7   Transmissão     301 non-null    object
#  8   Donos           301 non-null    int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 21.3+ KB

# %%
#dispersão
sns.set_theme(style='darkgrid')
sns.scatterplot(x='Preço_Venda', y='Preço_Atual', data=carros).set_title('Preço de Venda x Preço Atual')
# Out:
# Text(0.5, 1.0, 'Preço de Venda x Preço Atual')

# %%
#boxplot
sns.set_theme(style='ticks')
sns.boxplot(x='Tipo_Motor', y='Preço_Venda', data=carros).set_title('Preço de Venda x Tipo de Motor')
# Out:
# Text(0.5, 1.0, 'Preço de Venda x Tipo de Motor')

# %%
sns.boxplot(y='Preço_Venda', data=carros).set_title('Preço de Venda')
# Out:
# Text(0.5, 1.0, 'Preço de Venda')

# %%
#histograma
sns.set_theme(style='whitegrid')
sns.histplot(x='Km_Rodados', data=carros).set_title('Distribuição do Preço de Venda')
# Out:
# Text(0.5, 1.0, 'Distribuição do Preço de Venda')

# %%
#boxplot
sns.set_theme(style='dark')
bp=sns.barplot(x='Ano_Fabricação', y='Preço_Venda', data=carros)
bp.set_xticklabels(bp.get_xticklabels(),rotation=30)
bp.set_title('Preço de Venda x Ano de Fabricação')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_13188\948312877.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bp.set_xticklabels(bp.get_xticklabels(),rotation=30)
# Text(0.5, 1.0, 'Preço de Venda x Ano de Fabricação')
