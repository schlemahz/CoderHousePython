# %% [markdown]
# Mão na massa

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fastfood=pd.read_excel('fastfood.xlsx')

# %%
fastfood.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   restaurant   515 non-null    object
#  1   item         515 non-null    object
#  2   calories     515 non-null    int64
#  3   cal_fat      515 non-null    int64
#  4   total_fat    515 non-null    int64
#  5   sat_fat      515 non-null    object
#  6   trans_fat    515 non-null    object
#  7   cholesterol  515 non-null    int64
#  8   sodium       515 non-null    int64
#  9   total_carb   515 non-null    int64
#  10  fiber        503 non-null    float64
#  11  sugar        515 non-null    int64
#  12  protein      514 non-null    float64
#  13  vit_a        301 non-null    float64
#  14  vit_c        305 non-null    float64
#  15  calcium      305 non-null    float64
#  16  salad        515 non-null    object
# dtypes: float64(5), int64(7), object(5)
# memory usage: 68.5+ KB

# %%
fastfood.head(3)
# Out:
#   restaurant                              item  calories  cal_fat  total_fat  \
# 0  Mcdonalds  Artisan Grilled Chicken Sandwich       380       60          7
# 1  Mcdonalds    Single Bacon Smokehouse Burger       840      410         45
# 2  Mcdonalds    Double Bacon Smokehouse Burger      1130      600         67
#
#   sat_fat            trans_fat  cholesterol  sodium  total_carb  fiber  sugar  \
# 0       2                    0           95    1110          44    3.0     11
# 1      17  2023-05-01 00:00:00          130    1580          62    2.0     18
# 2      27                    3          220    1920          63    3.0     18
#
#    protein  vit_a  vit_c  calcium  salad
# 0     37.0    4.0   20.0     20.0  Other
# 1     46.0    6.0   20.0     20.0  Other
# 2     70.0   10.0   20.0     50.0  Other

# %%
restaurantes
# Out:
#     restaurant  quantidade
# 0    Taco Bell         115
# 1       Subway          96
# 2  Burger King          70
# 3    Mcdonalds          57
# 4        Arbys          55
# 5        Sonic          53
# 6  Dairy Queen          42
# 7  Chick Fil-A          27

# %%
fig,ax = plt.subplots()
restaurantes=fastfood.restaurant.value_counts(dropna=False).reset_index().rename({'count':'quantidade'}, axis=1)
ax.bar(restaurantes.restaurant, restaurantes.quantidade, color='gold')
ax.tick_params(axis='x', labelrotation=90)
ax.set_title('Restaurantes')
# Out:
# Text(0.5, 1.0, 'Restaurantes')

# %%
fig,ax = plt.subplots()
ax.hist(fastfood.calories, color='darkslategray')
ax.set_title('Calorias')
# Out:
# Text(0.5, 1.0, 'Calorias')

# %%
bp=sns.boxplot(fastfood.cholesterol, color='deeppink')
bp.set_title('Colesterol')
# Out:
# Text(0.5, 1.0, 'Colesterol')

# %%
bp=sns.boxplot(y='cholesterol', x='restaurant', data=fastfood)
bp.set_xticklabels(bp.get_xticklabels(),rotation=30)
bp.set_title('Colesterol x Restaurante')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_17852\316456335.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bp.set_xticklabels(bp.get_xticklabels(),rotation=30)
# Text(0.5, 1.0, 'Colesterol x Restaurante')

# %%
dp=sns.scatterplot(x='sodium', y='protein', data=fastfood)
dp.set_title('Sódio x Proteina')
# Out:
# Text(0.5, 1.0, 'Sódio x Proteina')

# %%
dp=sns.scatterplot(x='sodium', y='protein', hue='restaurant', data=fastfood)
dp.set_title('Sódio x Proteina por Restaurante')
# Out:
# Text(0.5, 1.0, 'Sódio x Proteina por Restaurante')

# %%
dp=sns.scatterplot(x='sodium', y='protein', hue='calcium', data=fastfood)
dp.set_title('Sódio x Proteina por Cálcio')
# Out:
# Text(0.5, 1.0, 'Sódio x Proteina por Cálcio')
