# %%
pip install missingno
# Out:
# Collecting missingno
#   Using cached missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy in c:\users\gabriel\appdata\local\programs\python\python313\lib\site-packages (from missingno) (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\gabriel\appdata\local\programs\python\python313\lib\site-packages (from missingno) (3.9.2)
# Collecting scipy (from missingno)
#   Downloading scipy-1.14.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: seaborn in c:\users\gabriel\appdata\local\programs\python\python313\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gabriel\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->missingno) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gabriel\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gabriel\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->missingno) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gabriel\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->missingno) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\gabriel\appdata\roaming\python\python313\site-packages (from matplotlib->missingno) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\gabriel\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->missingno) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gabriel\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->missingno) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gabriel\appdata\roaming\python\python313\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\gabriel\appdata\local\programs\python\python313\lib\site-packages (from seaborn->missingno) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gabriel\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gabriel\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\gabriel\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Using cached missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading scipy-1.14.1-cp313-cp313-win_amd64.whl (44.5 MB)
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#     --------------------------------------- 1.0/44.5 MB 5.9 MB/s eta 0:00:08
#    -- ------------------------------------- 2.4/44.5 MB 6.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.2/44.5 MB 9.2 MB/s eta 0:00:05
#    ------- -------------------------------- 7.9/44.5 MB 10.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 12.1/44.5 MB 12.4 MB/s eta 0:00:03
#    ------------------ --------------------- 20.7/44.5 MB 17.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 32.8/44.5 MB 23.6 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.5 MB 28.3 MB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 MB 27.5 MB/s eta 0:00:00
# Installing collected packages: scipy, missingno
# Successfully installed missingno-0.5.2 scipy-1.14.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import missingno as msno

# %% [markdown]
# Stack e unstack

# %%
casas=pd.read_csv('Dataset - Preço de Casas.csv', encoding='latin1', sep=' ', decimal=',')
casas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pés²           50000 non-null  int64
#  1   Quartos        50000 non-null  int64
#  2   Banheiros      50000 non-null  int64
#  3   Vizinhança     50000 non-null  object
#  4   AnoConstrução  50000 non-null  int64
#  5   Preço($)       50000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.3+ MB

# %%
casas.head()
# Out:
#    Pés²  Quartos  Banheiros Vizinhança  AnoConstrução       Preço($)
# 0  2126        4          1      Rural           1969  215355.283618
# 1  2459        3          2      Rural           1980  195014.221626
# 2  1860        2          1   Subúrbio           1970  306891.012076
# 3  2294        2          1     Urbano           1996  206786.787153
# 4  2130        5          2   Subúrbio           2001  272436.239065

# %%
casas.iloc[:,[1,2,3,5]].head()
# Out:
#    Quartos  Banheiros Vizinhança       Preço($)
# 0        4          1      Rural  215355.283618
# 1        3          2      Rural  195014.221626
# 2        2          1   Subúrbio  306891.012076
# 3        2          1     Urbano  206786.787153
# 4        5          2   Subúrbio  272436.239065

# %%
stack_casas=casas.iloc[:,[1,2,3,5]].stack()
stack_casas.head(20)
# Out:
# 0  Quartos                   4
#    Banheiros                 1
#    Vizinhança            Rural
#    Preço($)      215355.283618
# 1  Quartos                   3
#    Banheiros                 2
#    Vizinhança            Rural
#    Preço($)      195014.221626
# 2  Quartos                   2
#    Banheiros                 1
#    Vizinhança         Subúrbio
#    Preço($)      306891.012076
# 3  Quartos                   2
#    Banheiros                 1
#    Vizinhança           Urbano
#    Preço($)      206786.787153
# 4  Quartos                   5
#    Banheiros                 2
#    Vizinhança         Subúrbio
#    Preço($)      272436.239065
# dtype: object

# %%
stack_casas.unstack()
# Out:
#       Quartos Banheiros Vizinhança       Preço($)
# 0           4         1      Rural  215355.283618
# 1           3         2      Rural  195014.221626
# 2           2         1   Subúrbio  306891.012076
# 3           2         1     Urbano  206786.787153
# 4           5         2   Subúrbio  272436.239065
# ...       ...       ...        ...            ...
# 49995       5         3      Rural  100080.865895
# 49996       2         2   Subúrbio  374507.656727
# 49997       5         3   Subúrbio   384110.55559
# 49998       5         2      Rural  380512.685957
# 49999       5         3      Rural  221618.583218
#
# [50000 rows x 4 columns]

# %% [markdown]
# MultiIndex

# %%
tab_crostab=pd.crosstab([casas['Quartos'],casas['Banheiros']],casas['Vizinhança'])
tab_crostab#.reset_index()
# Out:
# Vizinhança         Rural  Subúrbio  Urbano
# Quartos Banheiros
# 2       1           1373      1399    1455
#         2           1429      1373    1381
#         3           1316      1365    1345
# 3       1           1394      1436    1435
#         2           1390      1426    1365
#         3           1389      1444    1382
# 4       1           1416      1356    1344
#         2           1382      1432    1367
#         3           1402      1372    1364
# 5       1           1423      1357    1367
#         2           1410      1383    1381
#         3           1352      1378    1417

# %%
tab_crostab.stack().head(18)
# Out:
# Quartos  Banheiros  Vizinhança
# 2        1          Rural         1373
#                     Subúrbio      1399
#                     Urbano        1455
#          2          Rural         1429
#                     Subúrbio      1373
#                     Urbano        1381
#          3          Rural         1316
#                     Subúrbio      1365
#                     Urbano        1345
# 3        1          Rural         1394
#                     Subúrbio      1436
#                     Urbano        1435
#          2          Rural         1390
#                     Subúrbio      1426
#                     Urbano        1365
#          3          Rural         1389
#                     Subúrbio      1444
#                     Urbano        1382
# dtype: int64

# %% [markdown]
# Explode

# %%
ps=pd.read_csv('Dataset - Poluição atmosférica.csv', sep=';')
ps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1106 entries, 0 to 1105
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Data        1106 non-null   object
#  1   País        1106 non-null   object
#  2   Status      1106 non-null   object
#  3   IQA         1106 non-null   int64
#  4   Unnamed: 4  0 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 43.3+ KB

# %%
ps.dropna(axis=1, how='all', inplace=True)
ps
# Out:
#             Data        País     Status  IQA
# 0     12/01/2023     Albania        Bom    9
# 1     12/01/2023     Algeria   Moderado   65
# 2     12/01/2023     Andorra        Bom    9
# 3     12/01/2023      Angola        Bom   45
# 4     12/01/2023   Argentina        Bom   19
# ...          ...         ...        ...  ...
# 1101  11/05/2023  Uzbekistan   Moderado   57
# 1102  11/05/2023     Vatican        Bom   50
# 1103  11/05/2023   Venezuela        Bom   17
# 1104  11/05/2023     Vietnam  Modderado   94
# 1105  11/05/2023      Zambia  Modderado   67
#
# [1106 rows x 4 columns]

# %%
ps['Data_valor']=ps.Data.str.split('/')
ps
# Out:
#             Data        País     Status  IQA      Data_valor
# 0     12/01/2023     Albania        Bom    9  [12, 01, 2023]
# 1     12/01/2023     Algeria   Moderado   65  [12, 01, 2023]
# 2     12/01/2023     Andorra        Bom    9  [12, 01, 2023]
# 3     12/01/2023      Angola        Bom   45  [12, 01, 2023]
# 4     12/01/2023   Argentina        Bom   19  [12, 01, 2023]
# ...          ...         ...        ...  ...             ...
# 1101  11/05/2023  Uzbekistan   Moderado   57  [11, 05, 2023]
# 1102  11/05/2023     Vatican        Bom   50  [11, 05, 2023]
# 1103  11/05/2023   Venezuela        Bom   17  [11, 05, 2023]
# 1104  11/05/2023     Vietnam  Modderado   94  [11, 05, 2023]
# 1105  11/05/2023      Zambia  Modderado   67  [11, 05, 2023]
#
# [1106 rows x 5 columns]

# %%
ps_ajsutado=ps.explode('Data_valor')
ps_ajsutado.head(9)
# Out:
#          Data     País    Status  IQA Data_valor
# 0  12/01/2023  Albania       Bom    9         12
# 0  12/01/2023  Albania       Bom    9         01
# 0  12/01/2023  Albania       Bom    9       2023
# 1  12/01/2023  Algeria  Moderado   65         12
# 1  12/01/2023  Algeria  Moderado   65         01
# 1  12/01/2023  Algeria  Moderado   65       2023
# 2  12/01/2023  Andorra       Bom    9         12
# 2  12/01/2023  Andorra       Bom    9         01
# 2  12/01/2023  Andorra       Bom    9       2023

# %%
ps_ajsutado.index.value_counts()
# Out:
# 1105    3
# 0       3
# 1089    3
# 1088    3
# 1087    3
#        ..
# 6       3
# 5       3
# 4       3
# 3       3
# 2       3
# Name: count, Length: 1106, dtype: int64

# %%
ps_ajsutado['Data_tipo']=['dia','mes','ano']*len(ps)
ps_ajsutado.tail(9)
# Out:
#             Data       País     Status  IQA Data_valor Data_tipo
# 1103  11/05/2023  Venezuela        Bom   17         11       dia
# 1103  11/05/2023  Venezuela        Bom   17         05       mes
# 1103  11/05/2023  Venezuela        Bom   17       2023       ano
# 1104  11/05/2023    Vietnam  Modderado   94         11       dia
# 1104  11/05/2023    Vietnam  Modderado   94         05       mes
# 1104  11/05/2023    Vietnam  Modderado   94       2023       ano
# 1105  11/05/2023     Zambia  Modderado   67         11       dia
# 1105  11/05/2023     Zambia  Modderado   67         05       mes
# 1105  11/05/2023     Zambia  Modderado   67       2023       ano

# %%
ps_ajsutado[(ps_ajsutado.Data_tipo=='mes')].Data_valor.value_counts()
# Out:
# Data_valor
# 04    558
# 05    275
# 03    138
# 01    135
# Name: count, dtype: int64

# %%
ps_ajsutado[(ps_ajsutado.Data_tipo=='mes')&(ps_ajsutado.Data_valor=='04')].IQA.mean()
# Out:
# np.float64(75.30286738351255)

# %%
ps[pd.to_datetime(ps.Data, format='%d/%m/%Y').dt.month==4].IQA.mean()
# Out:
# np.float64(75.30286738351255)

# %% [markdown]
# Pivot e pivot table

# %%
#pivot
df=pd.DataFrame()
df['Grupo']=['A']*2+['B']*2
df['Categoria']=['X','Y']*2
df['Ano']=[2019,2020]*2
df['Valor']=range(10,40+1,10)
df
# Out:
#   Grupo Categoria   Ano  Valor
# 0     A         X  2019     10
# 1     A         Y  2020     20
# 2     B         X  2019     30
# 3     B         Y  2020     40

# %%
df.pivot(index='Grupo',columns='Ano', values='Valor')
# Out:
# Ano    2019  2020
# Grupo
# A        10    20
# B        30    40

# %%
#pivot table
casas.head()
# Out:
#    Pés²  Quartos  Banheiros Vizinhança  AnoConstrução       Preço($)
# 0  2126        4          1      Rural           1969  215355.283618
# 1  2459        3          2      Rural           1980  195014.221626
# 2  1860        2          1   Subúrbio           1970  306891.012076
# 3  2294        2          1     Urbano           1996  206786.787153
# 4  2130        5          2   Subúrbio           2001  272436.239065

# %%
pd.pivot_table(casas, index='Vizinhança', columns='Banheiros', values='Preço($)', aggfunc='mean').round(2)
# Out:
# Banheiros           1          2          3
# Vizinhança
# Rural       221252.78  225193.55  225922.80
# Subúrbio    220068.99  223262.68  226376.42
# Urbano      224587.38  227507.18  229499.38

# %% [markdown]
# Dtype e astype

# %%
casas.dtypes
# Out:
# Pés²               int64
# Quartos            int64
# Banheiros          int64
# Vizinhança        object
# AnoConstrução      int64
# Preço($)         float64
# dtype: object

# %%
casas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pés²           50000 non-null  int64
#  1   Quartos        50000 non-null  int64
#  2   Banheiros      50000 non-null  int64
#  3   Vizinhança     50000 non-null  object
#  4   AnoConstrução  50000 non-null  int64
#  5   Preço($)       50000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.3+ MB

# %%
casas.Quartos=casas.Quartos.astype(str)
casas.dtypes
# Out:
# Pés²               int64
# Quartos           object
# Banheiros          int64
# Vizinhança        object
# AnoConstrução      int64
# Preço($)         float64
# dtype: object

# %% [markdown]
# Missing

# %%
pokemons=pd.read_csv('Dataset - Pokemon.csv', index_col=0)
pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1028 entries, 0 to 1027
# Data columns (total 32 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   abilities_number  1028 non-null   int64
#  1   ability_1         1024 non-null   object
#  2   ability_2         512 non-null    object
#  3   ability_hidden    810 non-null    object
#  4   attack            1027 non-null   float64
#  5   base_experience   923 non-null    float64
#  6   base_friendship   923 non-null    float64
#  7   catch_rate        923 non-null    float64
#  8   defense           1027 non-null   float64
#  9   egg_cycles        1026 non-null   float64
#  10  egg_type_1        1024 non-null   object
#  11  egg_type_2        282 non-null    object
#  12  egg_type_number   1028 non-null   int64
#  13  generation        1028 non-null   int64
#  14  growth_rate       1026 non-null   object
#  15  height_m          1027 non-null   float64
#  16  hp                1027 non-null   float64
#  17  is_legendary      1028 non-null   int64
#  18  is_mythical       1028 non-null   int64
#  19  is_sub_legendary  1028 non-null   int64
#  20  name              1028 non-null   object
#  21  percentage_male   791 non-null    float64
#  22  pokedex_number    1028 non-null   int64
#  23  sp_attack         1027 non-null   float64
#  24  sp_defense        1027 non-null   float64
#  25  species           1027 non-null   object
#  26  speed             1027 non-null   float64
#  27  total_points      1027 non-null   float64
#  28  type_1            1027 non-null   object
#  29  type_2            541 non-null    object
#  30  type_number       1028 non-null   int64
#  31  weight_kg         1026 non-null   float64
# dtypes: float64(14), int64(8), object(10)
# memory usage: 265.0+ KB

# %%
pokemons.columns
# Out:
# Index(['abilities_number', 'ability_1', 'ability_2', 'ability_hidden',
#        'attack', 'base_experience', 'base_friendship', 'catch_rate', 'defense',
#        'egg_cycles', 'egg_type_1', 'egg_type_2', 'egg_type_number',
#        'generation', 'growth_rate', 'height_m', 'hp', 'is_legendary',
#        'is_mythical', 'is_sub_legendary', 'name', 'percentage_male',
#        'pokedex_number', 'sp_attack', 'sp_defense', 'species', 'speed',
#        'total_points', 'type_1', 'type_2', 'type_number', 'weight_kg'],
#       dtype='object')

# %%
pokemons.head()
# Out:
#    abilities_number  ability_1 ability_2 ability_hidden  attack  \
# 0                 2   Overgrow       NaN    Chlorophyll    49.0
# 1                 2   Overgrow       NaN    Chlorophyll    62.0
# 2                 2   Overgrow       NaN    Chlorophyll    82.0
# 3                 1  Thick Fat       NaN            NaN   100.0
# 4                 2      Blaze       NaN    Solar Power    52.0
#
#    base_experience  base_friendship  catch_rate  defense  egg_cycles  ...  \
# 0             64.0             70.0        45.0     49.0        20.0  ...
# 1            142.0             70.0        45.0     63.0        20.0  ...
# 2            236.0             70.0        45.0     83.0        20.0  ...
# 3            281.0             70.0        45.0    123.0        20.0  ...
# 4             62.0             70.0        45.0     43.0        20.0  ...
#
#   pokedex_number sp_attack  sp_defense         species speed  total_points  \
# 0              1      65.0        65.0    Seed Pokémon  45.0         318.0
# 1              2      80.0        80.0    Seed Pokémon  60.0         405.0
# 2              3     100.0       100.0    Seed Pokémon  80.0         525.0
# 3              3     122.0       120.0    Seed Pokémon  80.0         625.0
# 4              4      60.0        50.0  Lizard Pokémon  65.0         309.0
#
#    type_1  type_2  type_number  weight_kg
# 0   Grass  Poison            2        6.9
# 1   Grass  Poison            2       13.0
# 2   Grass  Poison            2      100.0
# 3   Grass  Poison            2      155.5
# 4    Fire     NaN            1        8.5
#
# [5 rows x 32 columns]

# %%
pokemons[~pokemons.isna()]
# Out:
# 1028

# %%
pokemons[pokemons.ability_1.isna()]
# Out:
#       abilities_number ability_1 ability_2 ability_hidden  attack  \
# 33                   1       NaN       NaN  Lightning Rod    80.0
# 170                  1       NaN       NaN   Anticipation    75.0
# 240                  1       NaN       NaN    Regenerator     NaN
# 1027                 0       NaN       NaN            NaN   115.0
#
#       base_experience  base_friendship  catch_rate  defense  egg_cycles  ...  \
# 33              112.0             70.0       190.0     50.0        10.0  ...
# 170              65.0             70.0        45.0     70.0        35.0  ...
# 240               NaN              NaN         NaN      NaN         NaN  ...
# 1027              NaN              NaN         NaN    250.0       120.0  ...
#
#      pokedex_number sp_attack  sp_defense            species  speed  \
# 33               25      75.0        60.0      Mouse Pokémon  120.0
# 170             133      65.0        85.0  Evolution Pokémon   75.0
# 240             199       NaN         NaN                NaN    NaN
# 1027            890     125.0       250.0   Gigantic Pokémon  130.0
#
#       total_points    type_1  type_2  type_number  weight_kg
# 33           430.0  Electric     NaN            1        6.0
# 170          435.0    Normal     NaN            1        6.5
# 240            NaN       NaN     NaN            0        NaN
# 1027        1125.0    Poison  Dragon            2        NaN
#
# [4 rows x 32 columns]

# %%
pokemons[pokemons.ability_1.isnull()]
# Out:
#       abilities_number ability_1 ability_2 ability_hidden  attack  \
# 33                   1       NaN       NaN  Lightning Rod    80.0
# 170                  1       NaN       NaN   Anticipation    75.0
# 240                  1       NaN       NaN    Regenerator     NaN
# 1027                 0       NaN       NaN            NaN   115.0
#
#       base_experience  base_friendship  catch_rate  defense  egg_cycles  ...  \
# 33              112.0             70.0       190.0     50.0        10.0  ...
# 170              65.0             70.0        45.0     70.0        35.0  ...
# 240               NaN              NaN         NaN      NaN         NaN  ...
# 1027              NaN              NaN         NaN    250.0       120.0  ...
#
#      pokedex_number sp_attack  sp_defense            species  speed  \
# 33               25      75.0        60.0      Mouse Pokémon  120.0
# 170             133      65.0        85.0  Evolution Pokémon   75.0
# 240             199       NaN         NaN                NaN    NaN
# 1027            890     125.0       250.0   Gigantic Pokémon  130.0
#
#       total_points    type_1  type_2  type_number  weight_kg
# 33           430.0  Electric     NaN            1        6.0
# 170          435.0    Normal     NaN            1        6.5
# 240            NaN       NaN     NaN            0        NaN
# 1027        1125.0    Poison  Dragon            2        NaN
#
# [4 rows x 32 columns]

# %%
pokemons.abilities_number.value_counts()
# Out:
# abilities_number
# 3    510
# 2    299
# 1    218
# 0      1
# Name: count, dtype: int64

# %%
len(pokemons[pokemons.ability_1.isin(['Keen Eye','Run Away'])])
# Out:
# 46

# %%
# dropna (relembrando)
pokemons.dropna()
# Out:
#      abilities_number     ability_1      ability_2 ability_hidden  attack  \
# 45                  3  Poison Point        Rivalry    Sheer Force   102.0
# 59                  3  Effect Spore       Dry Skin           Damp    70.0
# 60                  3  Effect Spore       Dry Skin           Damp    95.0
# 103                 3     Oblivious      Own Tempo    Regenerator    65.0
# 104                 3     Oblivious      Own Tempo    Regenerator    75.0
# ..                ...           ...            ...            ...     ...
# 830                 3         Frisk    Infiltrator      Telepathy    70.0
# 864                 3  Honey Gather    Shield Dust     Sweet Veil    45.0
# 865                 3  Honey Gather    Shield Dust     Sweet Veil    55.0
# 904                 3    Iron Barbs  Lightning Rod         Sturdy    98.0
# 907                 3       Berserk     Sap Sipper     Cloud Nine    60.0
#
#      base_experience  base_friendship  catch_rate  defense  egg_cycles  ...  \
# 45             227.0             70.0        45.0     77.0        20.0  ...
# 59              57.0             70.0       190.0     55.0        20.0  ...
# 60             142.0             70.0        75.0     80.0        20.0  ...
# 103             63.0             70.0       190.0     65.0        20.0  ...
# 104            172.0             70.0        75.0    110.0        20.0  ...
# ..               ...              ...         ...      ...         ...  ...
# 830            187.0             70.0        45.0     80.0        20.0  ...
# 864             61.0             70.0       190.0     40.0        20.0  ...
# 865            162.0             70.0        75.0     60.0        20.0  ...
# 904            152.0             70.0       180.0     63.0        10.0  ...
# 907            170.0             70.0        70.0     85.0        20.0  ...
#
#     pokedex_number sp_attack  sp_defense              species  speed  \
# 45              34      85.0        75.0        Drill Pokémon   85.0
# 59              46      45.0        55.0     Mushroom Pokémon   25.0
# 60              47      60.0        80.0     Mushroom Pokémon   30.0
# 103             79      40.0        40.0        Dopey Pokémon   15.0
# 104             80     100.0        80.0  Hermit Crab Pokémon   30.0
# ..             ...       ...         ...                  ...    ...
# 830            715      97.0        80.0   Sound Wave Pokémon  123.0
# 864            742      55.0        40.0      Bee Fly Pokémon   84.0
# 865            743      95.0        70.0      Bee Fly Pokémon  124.0
# 904            777      40.0        73.0    Roly-Poly Pokémon   96.0
# 907            780     135.0        91.0       Placid Pokémon   36.0
#
#      total_points    type_1   type_2  type_number  weight_kg
# 45          505.0    Poison   Ground            2       62.0
# 59          285.0       Bug    Grass            2        5.4
# 60          405.0       Bug    Grass            2       29.5
# 103         315.0     Water  Psychic            2       36.0
# 104         490.0     Water  Psychic            2       78.5
# ..            ...       ...      ...          ...        ...
# 830         535.0    Flying   Dragon            2       85.0
# 864         304.0       Bug    Fairy            2        0.2
# 865         464.0       Bug    Fairy            2        0.5
# 904         435.0  Electric    Steel            2        3.3
# 907         485.0    Normal   Dragon            2      185.0
#
# [83 rows x 32 columns]

# %%
# fillna
pokemons.describe().round(0)
# Out:
#        abilities_number  attack  base_experience  base_friendship  catch_rate  \
# count            1028.0  1027.0            923.0            923.0       923.0
# mean                2.0    80.0            154.0             64.0        93.0
# std                 1.0    32.0             79.0             21.0        75.0
# min                 0.0     5.0             36.0              0.0         3.0
# 25%                 2.0    55.0             67.0             70.0        45.0
# 50%                 2.0    76.0            159.0             70.0        60.0
# 75%                 3.0   100.0            202.0             70.0       127.0
# max                 3.0   190.0            608.0            140.0       255.0
#
#        defense  egg_cycles  egg_type_number  generation  height_m  ...  \
# count   1027.0      1026.0           1028.0      1028.0    1027.0  ...
# mean      75.0        30.0              1.0         4.0       1.0  ...
# std       31.0        29.0              0.0         2.0       3.0  ...
# min        5.0         5.0              0.0         1.0       0.0  ...
# 25%       50.0        20.0              1.0         2.0       1.0  ...
# 50%       70.0        20.0              1.0         4.0       1.0  ...
# 75%       90.0        25.0              2.0         6.0       2.0  ...
# max      250.0       120.0              2.0         8.0     100.0  ...
#
#        is_mythical  is_sub_legendary  percentage_male  pokedex_number  \
# count       1028.0            1028.0            791.0          1028.0
# mean           0.0               0.0             55.0           438.0
# std            0.0               0.0             20.0           259.0
# min            0.0               0.0              0.0             1.0
# 25%            0.0               0.0             50.0           214.0
# 50%            0.0               0.0             50.0           434.0
# 75%            0.0               0.0             50.0           663.0
# max            1.0               1.0            100.0           890.0
#
#        sp_attack  sp_defense   speed  total_points  type_number  weight_kg
# count     1027.0      1027.0  1027.0        1027.0       1028.0     1026.0
# mean        73.0        72.0    69.0         438.0          2.0       70.0
# std         33.0        28.0    30.0         122.0          1.0      129.0
# min         10.0        20.0     5.0         175.0          0.0        0.0
# 25%         50.0        50.0    45.0         330.0          1.0        9.0
# 50%         65.0        70.0    65.0         455.0          2.0       29.0
# 75%         95.0        90.0    90.0         510.0          2.0       70.0
# max        194.0       250.0   180.0        1125.0          2.0     1000.0
#
# [8 rows x 22 columns]

# %%
pokemons_2=pokemons.copy()
pokemons_2.base_experience.fillna(0, inplace=True)
pokemons_2.describe().round(0)
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_14492\1200016605.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   pokemons_2.base_experience.fillna(0, inplace=True)
#        abilities_number  attack  base_experience  base_friendship  catch_rate  \
# count            1028.0  1027.0           1028.0            923.0       923.0
# mean                2.0    80.0            138.0             64.0        93.0
# std                 1.0    32.0             88.0             21.0        75.0
# min                 0.0     5.0              0.0              0.0         3.0
# 25%                 2.0    55.0             62.0             70.0        45.0
# 50%                 2.0    76.0            148.0             70.0        60.0
# 75%                 3.0   100.0            184.0             70.0       127.0
# max                 3.0   190.0            608.0            140.0       255.0
#
#        defense  egg_cycles  egg_type_number  generation  height_m  ...  \
# count   1027.0      1026.0           1028.0      1028.0    1027.0  ...
# mean      75.0        30.0              1.0         4.0       1.0  ...
# std       31.0        29.0              0.0         2.0       3.0  ...
# min        5.0         5.0              0.0         1.0       0.0  ...
# 25%       50.0        20.0              1.0         2.0       1.0  ...
# 50%       70.0        20.0              1.0         4.0       1.0  ...
# 75%       90.0        25.0              2.0         6.0       2.0  ...
# max      250.0       120.0              2.0         8.0     100.0  ...
#
#        is_mythical  is_sub_legendary  percentage_male  pokedex_number  \
# count       1028.0            1028.0            791.0          1028.0
# mean           0.0               0.0             55.0           438.0
# std            0.0               0.0             20.0           259.0
# min            0.0               0.0              0.0             1.0
# 25%            0.0               0.0             50.0           214.0
# 50%            0.0               0.0             50.0           434.0
# 75%            0.0               0.0             50.0           663.0
# max            1.0               1.0            100.0           890.0
#
#        sp_attack  sp_defense   speed  total_points  type_number  weight_kg
# count     1027.0      1027.0  1027.0        1027.0       1028.0     1026.0
# mean        73.0        72.0    69.0         438.0          2.0       70.0
# std         33.0        28.0    30.0         122.0          1.0      129.0
# min         10.0        20.0     5.0         175.0          0.0        0.0
# 25%         50.0        50.0    45.0         330.0          1.0        9.0
# 50%         65.0        70.0    65.0         455.0          2.0       29.0
# 75%         95.0        90.0    90.0         510.0          2.0       70.0
# max        194.0       250.0   180.0        1125.0          2.0     1000.0
#
# [8 rows x 22 columns]

# %%
pokemons_2.fillna({'base_experience':0})
pokemons_2.describe().round(0)
# Out:
#        abilities_number  attack  base_experience  base_friendship  catch_rate  \
# count            1028.0  1027.0           1028.0            923.0       923.0
# mean                2.0    80.0            138.0             64.0        93.0
# std                 1.0    32.0             88.0             21.0        75.0
# min                 0.0     5.0              0.0              0.0         3.0
# 25%                 2.0    55.0             62.0             70.0        45.0
# 50%                 2.0    76.0            148.0             70.0        60.0
# 75%                 3.0   100.0            184.0             70.0       127.0
# max                 3.0   190.0            608.0            140.0       255.0
#
#        defense  egg_cycles  egg_type_number  generation  height_m  ...  \
# count   1027.0      1026.0           1028.0      1028.0    1027.0  ...
# mean      75.0        30.0              1.0         4.0       1.0  ...
# std       31.0        29.0              0.0         2.0       3.0  ...
# min        5.0         5.0              0.0         1.0       0.0  ...
# 25%       50.0        20.0              1.0         2.0       1.0  ...
# 50%       70.0        20.0              1.0         4.0       1.0  ...
# 75%       90.0        25.0              2.0         6.0       2.0  ...
# max      250.0       120.0              2.0         8.0     100.0  ...
#
#        is_mythical  is_sub_legendary  percentage_male  pokedex_number  \
# count       1028.0            1028.0            791.0          1028.0
# mean           0.0               0.0             55.0           438.0
# std            0.0               0.0             20.0           259.0
# min            0.0               0.0              0.0             1.0
# 25%            0.0               0.0             50.0           214.0
# 50%            0.0               0.0             50.0           434.0
# 75%            0.0               0.0             50.0           663.0
# max            1.0               1.0            100.0           890.0
#
#        sp_attack  sp_defense   speed  total_points  type_number  weight_kg
# count     1027.0      1027.0  1027.0        1027.0       1028.0     1026.0
# mean        73.0        72.0    69.0         438.0          2.0       70.0
# std         33.0        28.0    30.0         122.0          1.0      129.0
# min         10.0        20.0     5.0         175.0          0.0        0.0
# 25%         50.0        50.0    45.0         330.0          1.0        9.0
# 50%         65.0        70.0    65.0         455.0          2.0       29.0
# 75%         95.0        90.0    90.0         510.0          2.0       70.0
# max        194.0       250.0   180.0        1125.0          2.0     1000.0
#
# [8 rows x 22 columns]

# %%
#gráfico de missing
msno.matrix(pokemons)
# Out:
# <Axes: >

# %%
# Out:
# Empty DataFrame
# Columns: [abilities_number, ability_1, ability_2, ability_hidden, attack, base_experience, base_friendship, catch_rate, defense, egg_cycles, egg_type_1, egg_type_2, egg_type_number, generation, growth_rate, height_m, hp, is_legendary, is_mythical, is_sub_legendary, name, percentage_male, pokedex_number, sp_attack, sp_defense, species, speed, total_points, type_1, type_2, type_number, weight_kg]
# Index: []
#
# [0 rows x 32 columns]
